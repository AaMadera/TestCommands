# %% [markdown]
# # Hash your email
# Change the value of variable `emailToHash` in order to get a hash of your email

# %%
import hashlib;
emailToHash = 'example@mail.com'

hashlib.md5((emailToHash.strip()).lower().encode("utf-8")).hexdigest()
# Out:
# 'fbf2b9cfc0a472389f3620e471bdf0e9'
